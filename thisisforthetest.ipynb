# %%
# !pytest ligotools
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.0, pytest-8.4.0, pluggy-1.6.0
# rootdir: /home/jovyan/hw3-emilyma214-alt
# configfile: pyproject.toml
# plugins: langsmith-0.3.45, nbval-0.11.0, pytest_notebook-0.10.0, hypothesis-6.135.1, cov-6.1.1, anyio-4.11.0
# collected 6 items
#
# ligotools/tests/test_readligo.py ...                                     [ 50%]
# ligotools/tests/test_utils.py ...                                        [100%]
#
# ============================== 6 passed in 1.38s ===============================
